# %%
import matplotlib.pyplot as plt

# Data
dimensions = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

speedup_data = {
    2: [1.14065, 0.965186, 1.00065, 1.33909, 0.950287, 0.98238, 0.987589, 0.95069, 0.986762, 0.942313],
    4: [1.43866, 1.06896, 1.03999, 0.94659, 1.00398, 0.96515, 1.20578, 1.05576, 0.980173, 1.0527],
    6: [2.40576, 1.01, 0.901015, 1.24368, 0.705723, 0.96866, 1.1014, 1.02684, 0.95956, 1.05085],
    8: [1.66913, 0.960253, 1.12241, 1.12315, 1.12874, 0.955607, 0.888311, 0.97291, 1.01777, 1.11852],
    10: [5.08437, 1.00406, 1.02457, 0.985467, 1.02441, 1.07653, 1.03442, 1.0157, 0.943149, 0.978434]
}

efficiency_data = {
    2: [0.570325, 0.482593, 0.500325, 0.669547, 0.475143, 0.49119, 0.493794, 0.475345, 0.493381, 0.471157],
    4: [0.359664, 0.267239, 0.259999, 0.236648, 0.250995, 0.241287, 0.301445, 0.26394, 0.245043, 0.263174],
    6: [0.40096, 0.168334, 0.150169, 0.207279, 0.117621, 0.161443, 0.183566, 0.17114, 0.159927, 0.175142],
    8: [0.208642, 0.120032, 0.140302, 0.140394, 0.141092, 0.119451, 0.111039, 0.121614, 0.127221, 0.139815],
    10: [0.508437, 0.100406, 0.102457, 0.0985467, 0.102441, 0.107653, 0.103442, 0.10157, 0.0943149, 0.0978434]
}

# Graph 1: N vs Speedup
plt.figure(figsize=(10, 6))
for num_processors, speedup_values in speedup_data.items():
    plt.plot(dimensions, speedup_values, marker='o', label=f'{num_processors} Processors')
plt.xlabel('Dimensions (N)')
plt.ylabel('Speedup')
plt.title('N vs Speedup for Different Numbers of Processors')
plt.legend()
plt.grid(True)

# Graph 2: N vs Efficiency
plt.figure(figsize=(10, 6))
for num_processors, efficiency_values in efficiency_data.items():
    plt.plot(dimensions, efficiency_values, marker='o', label=f'{num_processors} Processors')
plt.xlabel('Dimensions (N)')
plt.ylabel('Efficiency')
plt.title('N vs Efficiency for Different Numbers of Processors')
plt.legend()
plt.grid(True)

plt.show()
